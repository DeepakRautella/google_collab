# %%
import pandas as pd

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
#install mysql : You must install MySQL Server (https://dev.mysql.com/downloads/installer/)

# %%
cnx = mysql.connector.connect(user='root', password='********',
                              host='localhost',
                              port=3306,
                              database='world')

# %%
pd.read_sql_query('SELECT * FROM CITY',cnx)
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
pd.read_json('https://raw.githubusercontent.com/kodecocodes/recipes/master/Recipes.json')
# Out:
#                                               name  \
# 0                                  Crock Pot Roast
# 1                                Roasted Asparagus
# 2                         Curried Lentils and Rice
# 3                                  Big Night Pizza
# 4  Cranberry and Apple Stuffed Acorn Squash Recipe
# 5                             Mic's Yorkshire Puds
# 6                    Old-Fashioned Oatmeal Cookies
# 7                        Blueberry Oatmeal Squares
# 8                            Curried chicken salad
#
#                                          ingredients  \
# 0  [{'quantity': '1', 'name': ' beef roast', 'typ...
# 1  [{'quantity': '1 lb', 'name': ' asparagus', 't...
# 2  [{'quantity': '1 quart', 'name': 'beef broth',...
# 3  [{'quantity': '5 teaspoons', 'name': 'yeast', ...
# 4  [{'quantity': '2', 'name': 'acorn squash', 'ty...
# 5  [{'quantity': '200g', 'name': 'plain flour', '...
# 6  [{'quantity': '1 cup', 'name': 'raisins', 'typ...
# ...

# %%
pd.read_sql_query('SELECT * FROM COUNTRY',cnx)
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
pd.read_sql_query("SELECT * FROM COUNTRY WHERE Code like 'ZWE'",cnx)
# Out:
#   Code      Name Continent          Region  SurfaceArea  IndepYear  \
# 0  ZWE  Zimbabwe    Africa  Eastern Africa     390757.0       1980
#
#    Population  LifeExpectancy     GNP  GNPOld LocalName GovernmentForm  \
# 0    11669000            37.8  5951.0  8670.0  Zimbabwe       Republic
#
#         HeadOfState  Capital Code2
# 0  Robert G. Mugabe     4068    ZW

# %%
pd.read_sql_query("SELECT * FROM COUNTRY WHERE Code like 'IND'",cnx)
# Out:
#   Code   Name Continent                     Region  SurfaceArea  IndepYear  \
# 0  IND  India      Asia  Southern and Central Asia    3287263.0       1947
#
#    Population  LifeExpectancy       GNP    GNPOld     LocalName  \
# 0  1013662000            62.5  447114.0  430572.0  Bharat/India
#
#      GovernmentForm               HeadOfState  Capital Code2
# 0  Federal Republic  Kocheril Raman Narayanan     1109    IN
